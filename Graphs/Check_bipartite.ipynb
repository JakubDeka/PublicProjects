# %%
from graphs_utils import *

# %%
graph1 = {'a': ['b', 'c'],
          'b': ['a', 'c', 'd'],
          'c': ['a', 'b', 'd'],
          'd': ['b', 'c']
}
print_graph(graph1)
check_if_bipartite(graph1)
graph2 = {
    'a': ['b','c','d'],
    'b': ['a','c'],
    'c': ['a','b','d','e'],
    'd': ['a','c','e','f'],
    'e': ['c','d','f'],
    'f': ['d','e']
}
print_graph(graph2)
check_if_bipartite(graph2)
graph3 = {
    'a': ['b','c'],
    'b': ['a'],
    'c': ['a','d','e'],
    'd': ['c','f'],
    'e': ['c','f'],
    'f': ['d','e']
}
print_graph(graph3)
check_if_bipartite(graph3)
graph4 = {
    'a': ['b','c'],
    'b': ['a'],
    'c': ['a','d','e'],
    'd': ['c','f'],
    'e': ['c','f'],
    'f': ['d','e'],
    'g': ['h', 'i'],
    'h': ['g', 'i'],
    'i': ['g','h']
}
print_graph(graph4)
check_if_bipartite(graph4)
# Out:
# a :  b  c
# b :  a  c  d
# c :  a  b  d
# d :  b  c
# Graf nie jest dwudzielny
# a :  b  c  d
# b :  a  c
# c :  a  b  d  e
# d :  a  c  e  f
# e :  c  d  f
# f :  d  e
# Graf nie jest dwudzielny
# a :  b  c
# b :  a
# c :  a  d  e
# d :  c  f
# e :  c  f
# f :  d  e
# Graf jest dwudzielny
# a :  b  c
# b :  a
# c :  a  d  e
# d :  c  f
# e :  c  f
# f :  d  e
# g :  h  i
# h :  g  i
# i :  g  h
# Graf nie jest dwudzielny
