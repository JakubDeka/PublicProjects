# %% [markdown]
# # Cel ćwiczenia

# %% [markdown]
# Celem tego zadania jest stworzenie sieci neuronowej zdolnej do rozpoznawania czy twarz człowieka pokazana na zdjęciu jest prawdziwa, czy fałszywa (na zdjęciu została doklejona część innej twarzy).

# %% [markdown]
# # Zbiór danych

# %% [markdown]
# Dostaliśmy dane dla $3$ poziomów trudności fałszywych twarzy, oraz jeden większy zestaw zdjęć prawdziwych twarzy. Jedyną operacją zastosowaną do dostarczonych twarzy jest zeskalowanie wartości liczbowych pikseli z przedziału $[0, 255]$ do wartości z przedziału $[0, 1]$.
# Dodatkowo niektóre zdjęcia zostały odbite lustrzanie oraz obrócone.

# %% [markdown]
# # Zaproponowany model

# %% [markdown]
# W zadaniu jako najlepszy został wybrany model składający się z poniższych warstw:
# 1. warstwa wejściowa ($\ast$);
# 1. wartswa skaluja ($\ast$);
# 1. wartswa konwolucji ($\ast$);
# 1. warstwa poolująca (MaxPooling) ($\ast$);
# 1. wartswa konwolucji;
# 1. warstwa poolująca (MaxPooling);
# 1. warstwa wypłaszczająca ($\ast$);
# 1. warstwa $100$ neuronów ($\ast$) z uciętymi $15\%$ połączeń wejściowych;
# 1. warstwa $200$ neuronów z uciętymi $15\%$ połączeń wejściowych;
# 1. wyjściowa wartwa 2 neuronów ($\ast$).
#
# Wybrany dla tego modelu solver to "RMSprop", o współczynniku uczenia $0.001$, oraz funkcji straty "categorical_crossentropy".
#
# Wartwy z symbolem ($\ast$) oznaczają, że są one elementami bazowymi tworzonego modelu.

# %% [markdown]
# # Metodyka rozwiązywania zadania

# %% [markdown]
# Po wyjściu od bazowego modelu, w odpowiednich kolejnościach:
# * zmieniałem solver oraz funkcję straty modelu;
# * dodawałem:
#   *  warstwę konwolucji/poolingu;
#   * dodowałem wartwę neuronów;
# * blokowałem część połączeń w istniejących warstwach neuronów.

# %% [markdown]
# # Zestawienie wyników

# %% [markdown]
# Wyniki są przedstawiane na procesie uczenia modeli przebiegającym na $50$ epokach. Zestawiane są jedynie wybrane modele, z solverem 'adam' oraz funkcją straty 'categorical entropy'.

# %% [markdown]
# W poniższych zestawieniach wyrażenie "pre" oznacza moduł wartsw składający się z warstwy konwolucji o rozmiarze jądra $3$ na $3$ oraz dwóch filtrach i warstwy poolującej o rozmiarze $2$ na $2$, baza oznacza sieć opisaną za pomocą $(\ast)$ w poprzedniej sekcji "Zaproponowany model", a dropout - dołożoną jedną warstę neuronów z dropoutem $15\%$.

# %%
plt.figure(figsize=(20, 20))
plt.imshow(Image.open('/content/Test_plots_time.png'))
plt.axis("off")
# Out:
# (-0.5, 4799.5, 2399.5, -0.5)

# %%
plt.figure(figsize=(20, 20))
plt.imshow(Image.open('/content/Test_plots_loss.png'))
plt.axis("off")
# Out:
# (-0.5, 4799.5, 2399.5, -0.5)

# %%
plt.figure(figsize=(20, 20))
plt.imshow(Image.open('/content/Test_plots_precision.png'))
plt.axis("off")
# Out:
# (-0.5, 4799.5, 2399.5, -0.5)

# %% [markdown]
# Teraz tworzymy dwa modele na podstawie najlepeiej sprawujących się dotychczas modeli i porównujemy je dla trzech róznych solverów.
#
# Solvery te to "Adam", "SGD" oraz "RMSprop". Rozważane modele to:
# 1. 2 x pre i 2 x WN - czyli jest to sieć składająca się z dwóch modułów "pre", oraz 2 wartsw neuronów z wykluczonymi $15\%$ połączeń do poprzedniej warstwy;
# 1. 2 x pre i 3 x WN - czyli jest to sieć składająca się z dwóch modułów "pre", oraz 3 wartsw neuronów z wykluczonymi $15\%$ połączeń do poprzedniej warstwy.

# %%
plt.figure(figsize=(20, 20))
plt.imshow(Image.open('/content/Best_plots_time.png'))
plt.axis("off")
# Out:
# (-0.5, 4799.5, 2399.5, -0.5)

# %%
plt.figure(figsize=(20, 20))
plt.imshow(Image.open('/content/Best_plots_loss.png'))
plt.axis("off")
# Out:
# (-0.5, 4799.5, 2399.5, -0.5)

# %%
plt.figure(figsize=(20, 20))
plt.imshow(Image.open('/content/Best_plots_precision.png'))
plt.axis("off")
# Out:
# (-0.5, 4799.5, 2399.5, -0.5)

# %% [markdown]
# Mimo, że najlepszy na zbiorze uczącym wydaje się model "2 x pre i 3 x WN - RMSprop", to największą precyzję na zbiorze testowym osiągnął model "2 x pre i 2 x WN - RMSprop". Wyniki te dla tych modeli wyglądają nastepująco. Precyzja na zbiorze testowym dla modelu:
# 1. "2 x pre i 2 x WN - ADAM" to $50.00\%$;
# 1. "2 x pre i 2 x WN - SGD" to $56.67\%$;
# 1. "2 x pre i 2 x WN - RMSprop" to $58.89\%$;
# 1. "2 x pre i 3 x WN - ADAM" to $44.44\%$;
# 1. "2 x pre i 3 x WN - SGD" to $48.89\%$;
# 1. "2 x pre i 3 x WN - RMSprop" to $53.33\%$.
#
# Dla uwzględnienia uwagi, żadne z modeli "testowych" (poza dwoma najlepszymi) nie uzyskało tak wysokich wyników dla klasyfikacji zbioru testowego.</n>
#
# Ponadto czas działania "2 x pre i 2 x WN - RMSprop" jest również wyższy od wszystkich rozważanych tutaj modeli.

# %% [markdown]
# # Wnioski

# %% [markdown]
# Bazowy model jest zbyt prosty dla tego problemu, dlatego wynik jego działania to $50\%$ precyzji na zbiorze testowym.
#
# Największa precyzja została osiągnięta przez model z dwiema warstwami konowlucji i poolingu oraz model z pojedynczą wartwą neutronów z $10\%$ połączeń wyłączonych.

# %% [markdown]
# # Listing programu

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
import matplotlib.pyplot as plt
from google.colab import drive
from zipfile import ZipFile
import random as rd
import numpy as np
import os
from PIL import Image

# %%
rd.seed(9704)
tf.config.run_functions_eagerly(True)
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Rozpakowywanie plików .zip

# %% [markdown]
# ## Załadowanie zdjęć .jpg do środowiska

# %%
# directory = '/content/drive/MyDrive/Programowanie/DeepLearning/Zadanie_1-Rozpoznawanie_twarzy'

# %%
! cat '/content/drive/MyDrive/Programowanie/DeepLearning/Zadanie_1-Rozpoznawanie_twarzy/REAL.zip.001' '/content/drive/MyDrive/Programowanie/DeepLearning/Zadanie_1-Rozpoznawanie_twarzy/REAL.zip.002' > '/content/drive/MyDrive/Programowanie/DeepLearning/Zadanie_1-Rozpoznawanie_twarzy/Real.zip'

# %%
! unzip '/content/drive/MyDrive/Programowanie/DeepLearning/Zadanie_1-Rozpoznawanie_twarzy/Easy.zip' -d '/content/Easy'
! unzip '/content/drive/MyDrive/Programowanie/DeepLearning/Zadanie_1-Rozpoznawanie_twarzy/Medium.zip' -d '/content/Medium'
! unzip '/content/drive/MyDrive/Programowanie/DeepLearning/Zadanie_1-Rozpoznawanie_twarzy/Hard.zip' -d '/content/Hard'
! unzip '/content/drive/MyDrive/Programowanie/DeepLearning/Zadanie_1-Rozpoznawanie_twarzy/Real.zip' -d '/content/Real'

# %% [markdown]
# ### Zapisujemy zdjęcia w postaci array'i do zmiennych

# %%
difficulties = ['Easy', 'Medium', 'Hard', 'Real']

# %%
images = {'Easy': [], 'Medium': [], 'Hard': [], 'Real': []}

# %%
for difficulty in difficulties:
  for filename in os.listdir(difficulty):
    images[difficulty].append(Image.open(f'/content/{difficulty}/{filename}'))

# %% [markdown]
# ## Wyświetlamy obrazki z różnych zbiorów

# %%
plt.figure(figsize=(18, 18))
i = 1
for diff in difficulties:
  ax = plt.subplot(1, 4, i)
  plt.imshow(images[diff][0])
  plt.title(diff)
  plt.axis("off")
  i += 1

# %% [markdown]
# ## Tworzymy zbiory danych do uczenia i testowania

# %%
batch_size = 32
img_height = 600
img_width = 600

# %% [markdown]
# ### Zamieniamy zdjęcia na wartości liczbowe

# %%
images_n = images.copy()

# %%
for diff in difficulties:
  for i in range(len(images[diff])):
    images_n[diff][i] = np.asarray(images[diff][i])

# %%
easy = np.array(images_n['Easy'])
medium = np.array(images_n['Medium'])
hard = np.array(images_n['Hard'])
real = np.array(images_n['Real'])

# %% [markdown]
# ### Wybieramy poziom trudności zbioru i tworzymy zbiory data oraz labels

# %%
poziom = easy
length = len(poziom)

# %%
data = np.vstack((poziom, real[:length]))
labels = np.transpose(np.hstack((np.zeros((1, length)), np.ones((1, length)))))

# %% [markdown]
# ### Tworzymy zbiór uczący i testowy

# %%
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

# %%
# trainX, testX, trainY, testY = train_test_split(data, labels, test_size=0.2, random_state=997)
trainX, testX, trainY, testY = train_test_split(data, to_categorical(labels), test_size=0.2, random_state=123)

# %%
trainX.shape
# Out:
# (360, 600, 600, 3)

# %%
testX.shape
# Out:
# (90, 600, 600, 3)

# %%
trainY.shape
# Out:
# (360, 2)

# %%
testY.shape
# Out:
# (90, 2)

# %%
filepath = '/content/drive/MyDrive/Programowanie/DeepLearning/Zadanie_1-Rozpoznawanie_twarzy/EasySGD/'
checkpoint = keras.callbacks.ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %% [markdown]
# ## Tworzymy model/-e

# %% [markdown]
# ### Model bazowy

# %%
base_model = keras.models.Sequential([
    layers.Input(shape=(600, 600, 3)),
    layers.Rescaling(1./255),
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.SeparableConv2D(
        filters = 2,
        kernel_size=3, 
        padding="valid"),
    layers.MaxPool2D(pool_size = 2),
    layers.Flatten(),
    layers.Dense(200, activation = 'relu'),
    layers.Dense(2, activation = 'sigmoid')
    ]
    )

# %%
base_model.compile(optimizer = keras.optimizers.Adam(learning_rate=0.001), loss = "categorical_crossentropy", metrics = ['accuracy'])

# %%
# %timeit
base_model.fit(trainX, trainY, epochs = 50, batch_size = 32)

# %%
base_model.evaluate(testX, testY)

# %% [markdown]
# ### Modele testowe

# %%
model_1 = keras.models.Sequential([
    layers.Input(shape=(600, 600, 3)),
    layers.Rescaling(1./255),
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    # pierwszy pre
    ## dwie konwolucje
    layers.SeparableConv2D(
        filters = 3,
        kernel_size=3, 
        padding="valid"),    
    # layers.SeparableConv2D(
    #     filters = 2,
    #     kernel_size=3, 
    #     padding="valid"),
    # #pool
    layers.MaxPool2D(pool_size = 3),
    # drugi pre
    # jedna konwolucja
    layers.SeparableConv2D(
        filters = 2,
        kernel_size=3, 
        padding="valid"),
    # jeden pool
    layers.MaxPool2D(pool_size = 2),
    # spłaszczanie
    layers.Flatten(),
    # warstwy neuronowe
    #pierwsza
    layers.Dense(100, activation = 'relu'),
    layers.Dropout(0.15),
    # druga
    layers.Dense(150, activation = 'relu'),
    layers.Dropout(0.15),
    # trzecia
    # layers.Dense(100, activation = 'relu'),
    # layers.Dropout(0.15),
    # wyjściowa
    layers.Dense(2, activation = 'sigmoid')
    ]
    )

# %%
model_1.compile(optimizer = keras.optimizers.Adam(learning_rate=0.001), loss = "categorical_crossentropy", metrics = ['accuracy'])

# %%
# %timeit
model_1.fit(trainX, trainY, epochs = 50, batch_size = 32)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 5s 405ms/step - loss: 1.7015 - accuracy: 0.5028
# Epoch 2/50
# 12/12 [==============================] - 7s 555ms/step - loss: 0.8382 - accuracy: 0.5222
# Epoch 3/50
# 12/12 [==============================] - 5s 410ms/step - loss: 0.7295 - accuracy: 0.5361
# Epoch 4/50
# 12/12 [==============================] - 5s 409ms/step - loss: 0.7528 - accuracy: 0.4889
# Epoch 5/50
# 12/12 [==============================] - 5s 408ms/step - loss: 0.6988 - accuracy: 0.5389
# Epoch 6/50
# 12/12 [==============================] - 5s 399ms/step - loss: 0.7000 - accuracy: 0.5278
# Epoch 7/50
# 12/12 [==============================] - 5s 399ms/step - loss: 0.6866 - accuracy: 0.5222
# Epoch 8/50
# 12/12 [==============================] - 5s 405ms/step - loss: 0.6995 - accuracy: 0.5167
# Epoch 9/50
# 12/12 [==============================] - 5s 407ms/step - loss: 0.6864 - accuracy: 0.5083
# Epoch 10/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.6728 - accuracy: 0.5278
# Epoch 11/50
# 12/12 [==============================] - 5s 408ms/step - loss: 0.6853 - accuracy: 0.5306
# Epoch 12/50
# 12/12 [==============================] - 5s 407ms/step - loss: 0.6758 - accuracy: 0.5639
# Epoch 13/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.6800 - accuracy: 0.5694
# Epoch 14/50
# 12/12 [==============================] - 5s 415ms/step - loss: 0.6842 - accuracy: 0.5306
# Epoch 15/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6860 - accuracy: 0.5333
# Epoch 16/50
# 12/12 [==============================] - 5s 413ms/step - loss: 0.6898 - accuracy: 0.5500
# Epoch 17/50
# 12/12 [==============================] - 7s 540ms/step - loss: 0.6893 - accuracy: 0.5306
# Epoch 18/50
# 12/12 [==============================] - 7s 569ms/step - loss: 0.6781 - accuracy: 0.5417
# Epoch 19/50
# 12/12 [==============================] - 5s 438ms/step - loss: 0.6815 - accuracy: 0.5389
# Epoch 20/50
# 12/12 [==============================] - 5s 417ms/step - loss: 0.6801 - accuracy: 0.5361
# Epoch 21/50
# 12/12 [==============================] - 6s 483ms/step - loss: 0.6723 - accuracy: 0.5528
# Epoch 22/50
# 12/12 [==============================] - 5s 435ms/step - loss: 0.6768 - accuracy: 0.5278
# Epoch 23/50
# 12/12 [==============================] - 5s 429ms/step - loss: 0.7113 - accuracy: 0.5500
# Epoch 24/50
# 12/12 [==============================] - 5s 450ms/step - loss: 0.6858 - accuracy: 0.5444
# Epoch 25/50
# 12/12 [==============================] - 5s 406ms/step - loss: 0.6740 - accuracy: 0.5750
# Epoch 26/50
# 12/12 [==============================] - 5s 407ms/step - loss: 0.6701 - accuracy: 0.5417
# Epoch 27/50
# 12/12 [==============================] - 5s 406ms/step - loss: 0.6635 - accuracy: 0.5806
# Epoch 28/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.6742 - accuracy: 0.5556
# Epoch 29/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.6643 - accuracy: 0.5611
# Epoch 30/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6582 - accuracy: 0.5472
# Epoch 31/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.6743 - accuracy: 0.5528
# Epoch 32/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6672 - accuracy: 0.5611
# Epoch 33/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6507 - accuracy: 0.5806
# Epoch 34/50
# 12/12 [==============================] - 5s 399ms/step - loss: 0.6788 - accuracy: 0.5722
# Epoch 35/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6624 - accuracy: 0.5583
# Epoch 36/50
# 12/12 [==============================] - 5s 407ms/step - loss: 0.6907 - accuracy: 0.5500
# Epoch 37/50
# 12/12 [==============================] - 6s 516ms/step - loss: 0.6806 - accuracy: 0.5528
# Epoch 38/50
# 12/12 [==============================] - 5s 440ms/step - loss: 0.6908 - accuracy: 0.5250
# Epoch 39/50
# 12/12 [==============================] - 8s 727ms/step - loss: 0.6830 - accuracy: 0.5306
# Epoch 40/50
# 12/12 [==============================] - 7s 556ms/step - loss: 0.6813 - accuracy: 0.5194
# Epoch 41/50
# 12/12 [==============================] - 5s 421ms/step - loss: 0.6906 - accuracy: 0.5333
# Epoch 42/50
# 12/12 [==============================] - 6s 450ms/step - loss: 0.6655 - accuracy: 0.5583
# Epoch 43/50
# 12/12 [==============================] - 5s 433ms/step - loss: 0.6761 - accuracy: 0.5500
# Epoch 44/50
# 12/12 [==============================] - 6s 450ms/step - loss: 0.6812 - accuracy: 0.5528
# Epoch 45/50
# 12/12 [==============================] - 5s 450ms/step - loss: 0.6691 - accuracy: 0.5528
# Epoch 46/50
# 12/12 [==============================] - 5s 422ms/step - loss: 0.6626 - accuracy: 0.5833
# Epoch 47/50
# 12/12 [==============================] - 5s 431ms/step - loss: 0.6684 - accuracy: 0.5611
# Epoch 48/50
# 12/12 [==============================] - 5s 433ms/step - loss: 0.6693 - accuracy: 0.5667
# Epoch 49/50
# 12/12 [==============================] - 5s 413ms/step - loss: 0.6796 - accuracy: 0.5500
# Epoch 50/50
# 12/12 [==============================] - 5s 460ms/step - loss: 0.6736 - accuracy: 0.5583

# %%
model_1.evaluate(testX, testY)
# Out:
# 3/3 [==============================] - 0s 33ms/step - loss: 0.7208 - accuracy: 0.5000
# [0.7208308577537537, 0.5]

# %%
model_1.compile(optimizer = keras.optimizers.SGD(learning_rate=0.001), loss = "categorical_crossentropy", metrics = ['accuracy'])

# %%
# %timeit
model_1.fit(trainX, trainY, epochs = 50, batch_size = 32)

# %%
model_1.evaluate(testX, testY)

# %%
model_1.compile(optimizer = keras.optimizers.RMSprop(learning_rate=0.001), loss = "categorical_crossentropy", metrics = ['accuracy'])

# %%
# %timeit
model_1.fit(trainX, trainY, epochs = 50, batch_size = 32)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 5s 408ms/step - loss: 1.0408 - accuracy: 0.5111
# Epoch 2/50
# 12/12 [==============================] - 5s 407ms/step - loss: 0.7230 - accuracy: 0.4861
# Epoch 3/50
# 12/12 [==============================] - 6s 475ms/step - loss: 0.7050 - accuracy: 0.4972
# Epoch 4/50
# 12/12 [==============================] - 6s 471ms/step - loss: 0.6924 - accuracy: 0.4889
# Epoch 5/50
# 12/12 [==============================] - 5s 402ms/step - loss: 0.7141 - accuracy: 0.4667
# Epoch 6/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.7097 - accuracy: 0.5500
# Epoch 7/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.7121 - accuracy: 0.5083
# Epoch 8/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.6862 - accuracy: 0.5556
# Epoch 9/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.7095 - accuracy: 0.4889
# Epoch 10/50
# 12/12 [==============================] - 5s 408ms/step - loss: 0.6856 - accuracy: 0.5583
# Epoch 11/50
# 12/12 [==============================] - 5s 402ms/step - loss: 0.6798 - accuracy: 0.5694
# Epoch 12/50
# 12/12 [==============================] - 5s 422ms/step - loss: 0.7001 - accuracy: 0.5528
# Epoch 13/50
# 12/12 [==============================] - 6s 470ms/step - loss: 0.6794 - accuracy: 0.5556
# Epoch 14/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.6696 - accuracy: 0.5778
# Epoch 15/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.6801 - accuracy: 0.5778
# Epoch 16/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.6631 - accuracy: 0.6000
# Epoch 17/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6685 - accuracy: 0.5944
# Epoch 18/50
# 12/12 [==============================] - 5s 408ms/step - loss: 0.6679 - accuracy: 0.6333
# Epoch 19/50
# 12/12 [==============================] - 5s 416ms/step - loss: 0.6705 - accuracy: 0.5722
# Epoch 20/50
# 12/12 [==============================] - 5s 409ms/step - loss: 0.6703 - accuracy: 0.5889
# Epoch 21/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.6697 - accuracy: 0.5944
# Epoch 22/50
# 12/12 [==============================] - 5s 402ms/step - loss: 0.6905 - accuracy: 0.5333
# Epoch 23/50
# 12/12 [==============================] - 5s 406ms/step - loss: 0.6680 - accuracy: 0.5778
# Epoch 24/50
# 12/12 [==============================] - 5s 408ms/step - loss: 0.6543 - accuracy: 0.6000
# Epoch 25/50
# 12/12 [==============================] - 5s 405ms/step - loss: 0.6699 - accuracy: 0.5222
# Epoch 26/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6552 - accuracy: 0.6306
# Epoch 27/50
# 12/12 [==============================] - 5s 406ms/step - loss: 0.6542 - accuracy: 0.6167
# Epoch 28/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6175 - accuracy: 0.6417
# Epoch 29/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.6816 - accuracy: 0.5861
# Epoch 30/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.6387 - accuracy: 0.6083
# Epoch 31/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.6617 - accuracy: 0.5667
# Epoch 32/50
# 12/12 [==============================] - 5s 405ms/step - loss: 0.6404 - accuracy: 0.6194
# Epoch 33/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6640 - accuracy: 0.6111
# Epoch 34/50
# 12/12 [==============================] - 5s 406ms/step - loss: 0.6167 - accuracy: 0.6389
# Epoch 35/50
# 12/12 [==============================] - 5s 406ms/step - loss: 0.6400 - accuracy: 0.6056
# Epoch 36/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.6326 - accuracy: 0.6583
# Epoch 37/50
# 12/12 [==============================] - 5s 406ms/step - loss: 0.6754 - accuracy: 0.6194
# Epoch 38/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6536 - accuracy: 0.6250
# Epoch 39/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.6481 - accuracy: 0.6167
# Epoch 40/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6215 - accuracy: 0.6444
# Epoch 41/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.6352 - accuracy: 0.6333
# Epoch 42/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.6225 - accuracy: 0.6556
# Epoch 43/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6383 - accuracy: 0.6139
# Epoch 44/50
# 12/12 [==============================] - 5s 405ms/step - loss: 0.6180 - accuracy: 0.6500
# Epoch 45/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.6329 - accuracy: 0.6111
# Epoch 46/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.6188 - accuracy: 0.6444
# Epoch 47/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6007 - accuracy: 0.6250
# Epoch 48/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.5975 - accuracy: 0.6472
# Epoch 49/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.6279 - accuracy: 0.6306
# Epoch 50/50
# 12/12 [==============================] - 5s 400ms/step - loss: 0.6214 - accuracy: 0.6278

# %%
model_1.evaluate(testX, testY)
# Out:
# 3/3 [==============================] - 0s 39ms/step - loss: 0.6904 - accuracy: 0.5889
# [0.6904160976409912, 0.5888888835906982]

# %%
# model_1.save(filepath)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.

# %%
model_2 = keras.models.Sequential([
    layers.Input(shape=(600, 600, 3)),
    layers.Rescaling(1./255),
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    # pierwszy pre
    ## jedna konwolucja
    layers.SeparableConv2D(
        filters = 3,
        kernel_size=3, 
        padding="valid"),    
    ## pool
    layers.MaxPool2D(pool_size = 3),
    # drugi pre
    ## jedna konwolucja
    layers.SeparableConv2D(
        filters = 2,
        kernel_size=3, 
        padding="valid"),
    ## jeden pool
    layers.MaxPool2D(pool_size = 2),
    # spłaszczanie
    layers.Flatten(),
    # warstwy neuronowe
    ## pierwsza
    layers.Dense(100, activation = 'relu'),
    layers.Dropout(0.15),
    ## druga
    layers.Dense(150, activation = 'relu'),
    layers.Dropout(0.15),
    ## trzecia
    layers.Dense(100, activation = 'relu'),
    layers.Dropout(0.15),
    # wyjściowa
    layers.Dense(2, activation = 'sigmoid')
    ]
    )

# %%
model_2.compile(optimizer = keras.optimizers.Adam(learning_rate=0.001), loss = "categorical_crossentropy", metrics = ['accuracy'])

# %%
model_2.fit(trainX, trainY, epochs = 50, batch_size = 32)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/structured_function.py:265: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
# Epoch 1/50
# 12/12 [==============================] - 5s 411ms/step - loss: 0.9596 - accuracy: 0.4528
# Epoch 2/50
# 12/12 [==============================] - 5s 400ms/step - loss: 0.7547 - accuracy: 0.4694
# Epoch 3/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.7145 - accuracy: 0.4722
# Epoch 4/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6984 - accuracy: 0.5083
# Epoch 5/50
# 12/12 [==============================] - 6s 490ms/step - loss: 0.6994 - accuracy: 0.5250
# Epoch 6/50
# 12/12 [==============================] - 5s 416ms/step - loss: 0.6897 - accuracy: 0.5111
# Epoch 7/50
# 12/12 [==============================] - 5s 399ms/step - loss: 0.7098 - accuracy: 0.5028
# Epoch 8/50
# 12/12 [==============================] - 5s 398ms/step - loss: 0.6912 - accuracy: 0.5083
# Epoch 9/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.6958 - accuracy: 0.5083
# Epoch 10/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6797 - accuracy: 0.5667
# Epoch 11/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.6765 - accuracy: 0.5528
# Epoch 12/50
# 12/12 [==============================] - 5s 406ms/step - loss: 0.6789 - accuracy: 0.5556
# Epoch 13/50
# 12/12 [==============================] - 5s 407ms/step - loss: 0.6837 - accuracy: 0.5250
# Epoch 14/50
# 12/12 [==============================] - 5s 400ms/step - loss: 0.6829 - accuracy: 0.5528
# Epoch 15/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.6682 - accuracy: 0.5722
# Epoch 16/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.6765 - accuracy: 0.5833
# Epoch 17/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.6704 - accuracy: 0.5639
# Epoch 18/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.6668 - accuracy: 0.5833
# Epoch 19/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.6647 - accuracy: 0.5833
# Epoch 20/50
# 12/12 [==============================] - 5s 399ms/step - loss: 0.6507 - accuracy: 0.6139
# Epoch 21/50
# 12/12 [==============================] - 5s 405ms/step - loss: 0.6626 - accuracy: 0.5806
# Epoch 22/50
# 12/12 [==============================] - 6s 481ms/step - loss: 0.6614 - accuracy: 0.5778
# Epoch 23/50
# 12/12 [==============================] - 5s 408ms/step - loss: 0.6493 - accuracy: 0.5861
# Epoch 24/50
# 12/12 [==============================] - 5s 427ms/step - loss: 0.6483 - accuracy: 0.5889
# Epoch 25/50
# 12/12 [==============================] - 7s 563ms/step - loss: 0.6743 - accuracy: 0.5778
# Epoch 26/50
# 12/12 [==============================] - 5s 427ms/step - loss: 0.6468 - accuracy: 0.5917
# Epoch 27/50
# 12/12 [==============================] - 6s 474ms/step - loss: 0.6599 - accuracy: 0.6056
# Epoch 28/50
# 12/12 [==============================] - 6s 481ms/step - loss: 0.6609 - accuracy: 0.5694
# Epoch 29/50
# 12/12 [==============================] - 5s 398ms/step - loss: 0.6628 - accuracy: 0.5778
# Epoch 30/50
# 12/12 [==============================] - 5s 406ms/step - loss: 0.6582 - accuracy: 0.6000
# Epoch 31/50
# 12/12 [==============================] - 5s 448ms/step - loss: 0.6454 - accuracy: 0.6083
# Epoch 32/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.6422 - accuracy: 0.6167
# Epoch 33/50
# 12/12 [==============================] - 5s 397ms/step - loss: 0.6383 - accuracy: 0.6250
# Epoch 34/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6265 - accuracy: 0.6167
# Epoch 35/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6326 - accuracy: 0.6194
# Epoch 36/50
# 12/12 [==============================] - 5s 398ms/step - loss: 0.6304 - accuracy: 0.5861
# Epoch 37/50
# 12/12 [==============================] - 5s 400ms/step - loss: 0.6275 - accuracy: 0.6472
# Epoch 38/50
# 12/12 [==============================] - 5s 400ms/step - loss: 0.6487 - accuracy: 0.6028
# Epoch 39/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6173 - accuracy: 0.6139
# Epoch 40/50
# 12/12 [==============================] - 5s 402ms/step - loss: 0.6176 - accuracy: 0.6278
# Epoch 41/50
# 12/12 [==============================] - 5s 411ms/step - loss: 0.6255 - accuracy: 0.6333
# Epoch 42/50
# 12/12 [==============================] - 5s 402ms/step - loss: 0.6217 - accuracy: 0.6167
# Epoch 43/50
# 12/12 [==============================] - 5s 402ms/step - loss: 0.6337 - accuracy: 0.6111
# Epoch 44/50
# 12/12 [==============================] - 6s 494ms/step - loss: 0.6196 - accuracy: 0.6250
# Epoch 45/50
# 12/12 [==============================] - 5s 416ms/step - loss: 0.5947 - accuracy: 0.6417
# Epoch 46/50
# 12/12 [==============================] - 5s 402ms/step - loss: 0.6045 - accuracy: 0.6500
# Epoch 47/50
# 12/12 [==============================] - 5s 400ms/step - loss: 0.6405 - accuracy: 0.6000
# Epoch 48/50
# 12/12 [==============================] - 5s 431ms/step - loss: 0.6657 - accuracy: 0.5944
# Epoch 49/50
# 12/12 [==============================] - 6s 446ms/step - loss: 0.6320 - accuracy: 0.6000
# Epoch 50/50
# 12/12 [==============================] - 5s 433ms/step - loss: 0.6374 - accuracy: 0.6583

# %%
model_2.evaluate(testX, testY)
# Out:
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7504 - accuracy: 0.4444
# [0.7503863573074341, 0.4444444477558136]

# %%
model_2.compile(optimizer = keras.optimizers.SGD(learning_rate=0.001), loss = "categorical_crossentropy", metrics = ['accuracy'])

# %%
model_2.fit(trainX, trainY, epochs = 50, batch_size = 32)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 5s 400ms/step - loss: 0.6287 - accuracy: 0.6278
# Epoch 2/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.6520 - accuracy: 0.6028
# Epoch 3/50
# 12/12 [==============================] - 5s 436ms/step - loss: 0.6396 - accuracy: 0.6278
# Epoch 4/50
# 12/12 [==============================] - 5s 449ms/step - loss: 0.6298 - accuracy: 0.6361
# Epoch 5/50
# 12/12 [==============================] - 5s 402ms/step - loss: 0.6387 - accuracy: 0.6167
# Epoch 6/50
# 12/12 [==============================] - 5s 400ms/step - loss: 0.6345 - accuracy: 0.6111
# Epoch 7/50
# 12/12 [==============================] - 6s 472ms/step - loss: 0.6119 - accuracy: 0.6861
# Epoch 8/50
# 12/12 [==============================] - 5s 400ms/step - loss: 0.6294 - accuracy: 0.5972
# Epoch 9/50
# 12/12 [==============================] - 5s 411ms/step - loss: 0.6056 - accuracy: 0.6361
# Epoch 10/50
# 12/12 [==============================] - 6s 452ms/step - loss: 0.6607 - accuracy: 0.5778
# Epoch 11/50
# 12/12 [==============================] - 5s 411ms/step - loss: 0.6384 - accuracy: 0.6250
# Epoch 12/50
# 12/12 [==============================] - 6s 480ms/step - loss: 0.6168 - accuracy: 0.6194
# Epoch 13/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6295 - accuracy: 0.6389
# Epoch 14/50
# 12/12 [==============================] - 5s 428ms/step - loss: 0.6214 - accuracy: 0.6250
# Epoch 15/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6324 - accuracy: 0.6250
# Epoch 16/50
# 12/12 [==============================] - 5s 419ms/step - loss: 0.6537 - accuracy: 0.6000
# Epoch 17/50
# 12/12 [==============================] - 5s 433ms/step - loss: 0.6457 - accuracy: 0.5917
# Epoch 18/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6305 - accuracy: 0.6250
# Epoch 19/50
# 12/12 [==============================] - 5s 429ms/step - loss: 0.6233 - accuracy: 0.6667
# Epoch 20/50
# 12/12 [==============================] - 5s 400ms/step - loss: 0.6210 - accuracy: 0.6472
# Epoch 21/50
# 12/12 [==============================] - 5s 397ms/step - loss: 0.6245 - accuracy: 0.6111
# Epoch 22/50
# 12/12 [==============================] - 5s 411ms/step - loss: 0.5927 - accuracy: 0.6778
# Epoch 23/50
# 12/12 [==============================] - 6s 493ms/step - loss: 0.6736 - accuracy: 0.5861
# Epoch 24/50
# 12/12 [==============================] - 5s 400ms/step - loss: 0.6604 - accuracy: 0.5722
# Epoch 25/50
# 12/12 [==============================] - 5s 398ms/step - loss: 0.6281 - accuracy: 0.6250
# Epoch 26/50
# 12/12 [==============================] - 5s 400ms/step - loss: 0.6636 - accuracy: 0.5806
# Epoch 27/50
# 12/12 [==============================] - 5s 400ms/step - loss: 0.6502 - accuracy: 0.6028
# Epoch 28/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6151 - accuracy: 0.6278
# Epoch 29/50
# 12/12 [==============================] - 5s 400ms/step - loss: 0.6161 - accuracy: 0.6000
# Epoch 30/50
# 12/12 [==============================] - 5s 398ms/step - loss: 0.6355 - accuracy: 0.6083
# Epoch 31/50
# 12/12 [==============================] - 6s 503ms/step - loss: 0.6010 - accuracy: 0.6528
# Epoch 32/50
# 12/12 [==============================] - 5s 400ms/step - loss: 0.6509 - accuracy: 0.6278
# Epoch 33/50
# 12/12 [==============================] - 5s 402ms/step - loss: 0.6415 - accuracy: 0.6278
# Epoch 34/50
# 12/12 [==============================] - 5s 399ms/step - loss: 0.6156 - accuracy: 0.6444
# Epoch 35/50
# 12/12 [==============================] - 5s 399ms/step - loss: 0.6171 - accuracy: 0.6222
# Epoch 36/50
# 12/12 [==============================] - 5s 402ms/step - loss: 0.6248 - accuracy: 0.6250
# Epoch 37/50
# 12/12 [==============================] - 5s 397ms/step - loss: 0.6140 - accuracy: 0.6444
# Epoch 38/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.6832 - accuracy: 0.5444
# Epoch 39/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.6617 - accuracy: 0.5833
# Epoch 40/50
# 12/12 [==============================] - 5s 399ms/step - loss: 0.6704 - accuracy: 0.5861
# Epoch 41/50
# 12/12 [==============================] - 5s 399ms/step - loss: 0.6590 - accuracy: 0.5778
# Epoch 42/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6302 - accuracy: 0.6194
# Epoch 43/50
# 12/12 [==============================] - 5s 402ms/step - loss: 0.6420 - accuracy: 0.6389
# Epoch 44/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.6423 - accuracy: 0.6167
# Epoch 45/50
# 12/12 [==============================] - 5s 399ms/step - loss: 0.6406 - accuracy: 0.5917
# Epoch 46/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6192 - accuracy: 0.6333
# Epoch 47/50
# 12/12 [==============================] - 5s 401ms/step - loss: 0.6289 - accuracy: 0.6583
# Epoch 48/50
# 12/12 [==============================] - 5s 402ms/step - loss: 0.6293 - accuracy: 0.6361
# Epoch 49/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.6084 - accuracy: 0.6472
# Epoch 50/50
# 12/12 [==============================] - 5s 405ms/step - loss: 0.6041 - accuracy: 0.6361

# %%
model_2.evaluate(testX, testY)
# Out:
# 3/3 [==============================] - 0s 37ms/step - loss: 0.8163 - accuracy: 0.4889
# [0.816265881061554, 0.4888888895511627]

# %%
model_2.compile(optimizer = keras.optimizers.RMSprop(learning_rate=0.001), loss = "categorical_crossentropy", metrics = ['accuracy'])

# %%
model_2.fit(trainX, trainY, epochs = 50, batch_size = 32)

# %%
model_2.evaluate(testX, testY)
# Out:
# 3/3 [==============================] - 0s 32ms/step - loss: 1.1969 - accuracy: 0.5333
# [1.196934461593628, 0.5333333611488342]

# %% [markdown]
# ## Kod do wykresów

# %% [markdown]
# ### Macierze danych testy

# %%
baza = np.array([[10.431, 81.5598, 0.4694],
[5.394, 22.4229, 0.4750],
[5.411, 8.9759, 0.4861],
[5.402, 3.7397, 0.5278],
[5.391, 1.8160, 0.5389],
[5.392, 3.4825, 0.5306],
[5.390, 2.8225, 0.5083],
[5.392, 2.5476, 0.5278],
[5.389, 1.7744, 0.5167],
[5.390, 1.6294, 0.5667],
[5.391, 0.9505, 0.5667],
[5.425, 1.2203, 0.5528],
[6.530, 1.2506, 0.5306],
[6.535, 1.6449, 0.5389],
[7.632, 1.4147, 0.5000],
[5.397, 0.8662, 0.5139],
[5.391, 0.7880, 0.5250],
[5.410, 0.9192, 0.5472],
[5.433, 0.8219, 0.5694],
[5.422, 0.6003, 0.6639],
[5.424, 0.5942, 0.6667],
[5.425, 0.5804, 0.6889],
[5.427, 0.6097, 0.6333],
[5.424, 0.5869, 0.6806]])

# %% [markdown]
# ### Wykresy testowe

# %%
titles = ['time', 'loss', 'precision']
for i in range(3):
  plt.figure(figsize=(12, 6))
  plt.plot(baza[:, i], label="baza")
  plt.plot(dwa_x_pre[:, i], label="2 x pre")
  plt.plot(dropout[:, i], label="dropout")
  plt.plot(dwa_x_pre_i_drop[:, i], label="2 x pre i dropout")
  plt.plot(dwaXpre_i_dwaXneur_i_drop[:, i], label="2 x pre i więcej warstw neuronów")
  plt.title(titles[i])
  plt.legend(loc="upper left")
  plt.savefig(f"Test_plots_{titles[i]}.png", dpi=400)
  plt.show()

# %% [markdown]
# ### Dane najlepsze

# %%
dwa_neuronowe_ADAM = np.array([[5.405, 1.7015, 0.5028],
[7.555, 0.8382, 0.5222],
[5.410, 0.7295, 0.5361],
[5.409, 0.7528, 0.4889],
[5.408, 0.6988, 0.5389],
[5.399, 0.7000, 0.5278],
[5.399, 0.6866, 0.5222],
[5.405, 0.6995, 0.5167],
[5.407, 0.6864, 0.5083],
[5.404, 0.6728, 0.5278],
[5.408, 0.6853, 0.5306],
[5.407, 0.6758, 0.5639],
[5.404, 0.6800, 0.5694],
[5.415, 0.6842, 0.5306],
[5.403, 0.6860, 0.5333],
[5.413, 0.6898, 0.5500],
[7.540, 0.6893, 0.5306],
[7.569, 0.6781, 0.5417],
[5.438, 0.6815, 0.5389],
[5.417, 0.6801, 0.5361],
[6.483, 0.6723, 0.5528],
[5.435, 0.6768, 0.5278],
[5.429, 0.7113, 0.5500],
[5.450, 0.6858, 0.5444],
[5.406, 0.6740, 0.5750],
[5.407, 0.6701, 0.5417],
[5.406, 0.6635, 0.5806],
[5.404, 0.6742, 0.5556],
[5.404, 0.6643, 0.5611],
[5.403, 0.6582, 0.5472],
[5.404, 0.6743, 0.5528],
[5.403, 0.6672, 0.5611],
[5.403, 0.6507, 0.5806],
[5.399, 0.6788, 0.5722],
[5.403, 0.6624, 0.5583],
[5.407, 0.6907, 0.5500],
[6.516, 0.6806, 0.5528],
[5.440, 0.6908, 0.5250],
[8.727, 0.6830, 0.5306],
[7.556, 0.6813, 0.5194],
[5.421, 0.6906, 0.5333],
[6.450, 0.6655, 0.5583],
[5.433, 0.6761, 0.5500],
[6.450, 0.6812, 0.5528],
[5.450, 0.6691, 0.5528],
[5.422, 0.6626, 0.5833],
[5.431, 0.6684, 0.5611],
[5.433, 0.6693, 0.5667],
[5.413, 0.6796, 0.5500],
[5.460, 0.6736, 0.5583]])
dwa_neuronowe_SGD = np.array([[5.400, 0.6616, 0.6000],
[5.406, 0.7385, 0.5611],
[5.401, 0.6611, 0.5889],
[5.404, 0.6775, 0.5889],
[5.398, 0.6752, 0.5611],
[5.407, 0.7649, 0.5167],
[6.504, 0.6876, 0.5417],
[5.402, 0.6902, 0.5306],
[5.400, 0.6949, 0.5389],
[5.399, 0.6902, 0.5722],
[5.404, 0.6870, 0.5500],
[5.402, 0.6685, 0.5778],
[5.404, 0.6814, 0.5583],
[5.397, 0.6140, 0.6444],
[5.404, 0.6832, 0.5444],
[5.401, 0.6617, 0.5833],
[5.399, 0.6704, 0.5861],
[5.399, 0.6590, 0.5778],
[5.403, 0.6302, 0.6194],
[5.402, 0.6420, 0.6389],
[5.401, 0.6423, 0.6167],
[5.399, 0.6406, 0.5917],
[5.403, 0.6192, 0.6333],
[5.401, 0.6289, 0.6583],
[5.402, 0.6293, 0.6361],
[5.403, 0.6084, 0.6472],
[5.405, 0.6041, 0.6361]])
trzy_neuronowe_RMSprop = np.array([[5.402, 0.6630, 0.5889],
[5.404, 0.6222, 0.6417],
[5.403, 0.6179, 0.6167],
[5.403, 0.6226, 0.6278],
[5.399, 0.6195, 0.6500],
[5.402, 0.6129, 0.6222],
[5.404, 0.5929, 0.6472],
[5.402, 0.6051, 0.6444],
[5.404, 0.6106, 0.6472],
[5.402, 0.5933, 0.6667],
[5.402, 0.5877, 0.6583],
[5.397, 0.5821, 0.6778],
[5.399, 0.6154, 0.6389],
[5.402, 0.6017, 0.6583],
[5.402, 0.5597, 0.6722],
[5.401, 0.5901, 0.6667],
[5.401, 0.6115, 0.6722],
[5.399, 0.5571, 0.7000],
[5.399, 0.5839, 0.6806],
[5.410, 0.5907, 0.6611],
[5.407, 0.5887, 0.6972],
[5.412, 0.5736, 0.6639],
[5.402, 0.5770, 0.6694],
[5.403, 0.5409, 0.6972],
[5.403, 0.5648, 0.6694],
[5.396, 0.5971, 0.6583],
[5.396, 0.5847, 0.6972],
[5.399, 0.5423, 0.7139],
[5.403, 0.5985, 0.6583],
[5.400, 0.5445, 0.6722],
[5.399, 0.6078, 0.6722],
[5.400, 0.5654, 0.6639],
[5.402, 0.5253, 0.7139],
[7.568, 0.5616, 0.6972],
[6.491, 0.5717, 0.7000],
[6.449, 0.5445, 0.6917],
[6.459, 0.5835, 0.6806],
[6.506, 0.5505, 0.6861],
[7.576, 0.5779, 0.6750],
[5.403, 0.5479, 0.7056],
[5.400, 0.5445, 0.6972],
[5.400, 0.5367, 0.6917],
[5.399, 0.5148, 0.7167],
[5.402, 0.5301, 0.7056],
[5.397, 0.5194, 0.7167],
[5.402, 0.5557, 0.6833],
[5.405, 0.5536, 0.7250],
[5.402, 0.5715, 0.6917],
[5.397, 0.5365, 0.7222],
[5.401, 0.4887, 0.7583]])

# %% [markdown]
# ### Wykresy najlepsze

# %%
for i in range(3):
  plt.figure(figsize=(12, 6))
  plt.plot(dwa_neuronowe_ADAM[:, i], label="2 x pre i 2 x WN - ADAM")
  plt.plot(dwa_neuronowe_SGD[:, i], label="2 x pre i 2 x WN - SGD")
  plt.plot(dwa_neuronowe_RMSprop[:, i], label="2 x pre i 2 x WN - RMSprop")
  plt.plot(trzy_neuronowe_ADAM[:, i], label="2 x pre i 3 x WN - ADAM")
  plt.plot(trzy_neuronowe_SGD[:, i], label="2 x pre i 3 x WN - SGD")
  plt.plot(trzy_neuronowe_RMSprop[:, i], label="2 x pre i 3 x WN - RMSprop")
  plt.title(titles[i])
  plt.legend(loc="upper left")
  plt.savefig(f"Best_plots_{titles[i]}.png", dpi=400)
  plt.show()
